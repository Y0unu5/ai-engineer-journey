# %%
import pandas as pd
s=pd.Series([10,20,30,40,50])

s.iloc[3]

# %%
index=['Apple','Orange','Banana','Pineapple','Cherry']

s=pd.Series([10,20,30,40,50],index=index)
s.name='Fruits'

# %%
s

# %%
fruit_dict={'Apple':10,'Orange':20,'Banana':30,'Pineapple':40,'Cherry':50}        
s=pd.Series(fruit_dict, name='Protein')   
s
