# %% [markdown]
# # Module: File Handling Assignments
# ## Lesson: File Handling and Operations
# ### Assignment 1: Reading a File
#
# Write a function that reads the contents of a file named `sample.txt` and prints each line.

# %%
def read_file(filename):
    with open(filename, 'r') as file:
        for line in file:
            print(line.strip())
        file.close()

read_file('sample.txt')

# %% [markdown]
# ### Assignment 2: Writing to a File
#
# Write a function that writes a list of strings to a file named `output.txt`, with each string on a new line.

# %%
def write_list(filename, list ):
    with open(filename, 'w') as file:
        for item in list:
            file.write(item + '\n')
        file.close()

print(write_list('sample.txt', ['Hello', 'World', 'Hello World', 'Hello World Hello World']))

# %% [markdown]
# ### Assignment 3: Copying a File
#
# Write a function that copies the contents of a file named `source.txt` to a new file named `destination.txt`.

# %%
def copy_source_to_destination(source, destination):
    with open(source, 'r') as source_file:
        with open(destination, 'w') as destination_file:
            for line in source_file:
                destination_file.write(line)
            source_file.close()
            destination_file.close()

copy_source_to_destination('sample.txt', 'sample_copy.txt')

# %% [markdown]
# ### Assignment 4: Appending to a File
#
# Write a function that appends a given string to the end of a file named `log.txt`.

# %%
def append_string(filename, string):
    with open(filename, 'a') as file:
        file.write(string)
        file.close()

append_string('log.txt', 'Hello World')

# %% [markdown]
# ### Assignment 5: Counting Words in a File
#
# Write a function that reads the contents of a file named `document.txt` and returns the number of words in the file.

# %%
def count_words(filename):
    with open(filename, 'r') as file:
        words = file.read().split()
        file.close()
        return len(words)

count_words('merged_file.txt')

# %% [markdown]
# ### Assignment 6: Finding and Replacing Text
#
# Write a function that finds and replaces all occurrences of a given word in a file named `data.txt` with another word.

# %%
def replace_word(filename, old_word, new_word):
    with open(filename, 'r') as file:
        content = file.read()
        content = content.replace(old_word, new_word)
        file.close()
        with open(filename, 'w') as file:
            file.write(content)
            file.close()

replace_word('largefile_part1.txt', 'Java', 'Python')  # Replace 'Hello World' with 'Hi World' in 'largefile_part1', 'Hello', 'Hi')

# %% [markdown]
# ### Assignment 8: Counting Lines, Words, and Characters
#
# Write a function that reads the contents of a file named `stats.txt` and returns the number of lines, words, and characters in the file.

# %%
def count_lines(filename):
    with open(filename,'r') as file:
        lines=file.readlines()
        number_lines=len(lines)
        words= sum(len(line.split()) for line in lines)
        char_count=sum(len(line) for line in lines)
        return number_lines, words, char_count

print(count_lines('largefile_part1.txt'))

# %% [markdown]
# ### Assignment 9: Merging Multiple Files
#
# Write a function that merges the contents of multiple files into a single file named `merged.txt`.

# %%
def merge_file(file_list, output_file):
    with open(output_file, 'w') as outfile:
        for filename in file_list:
            with open(filename, 'r') as infile:
                outfile.write(infile.read())
                infile.close()
        outfile.close()

merge_file(['largefile_part1.txt', 'largefile_part2.txt'], 'merged_file.txt')

# %% [markdown]
# ### Assignment 10: Splitting a Large File
#
# Write a function that splits a large file named `large.txt` into smaller files of 100 lines each.

# %%
def split_large_file(large_file, lines_per_file):
    with open(large_file, 'r', encoding='utf-8', errors='ignore') as infile:
        part=1
        lines=[]

        for line in infile:
            lines.append(line.strip()+'\n')
            if len(lines) == lines_per_file:
                with open(f'{large_file}_part{part}.txt', 'w') as f:
                    f.writelines(lines)
                part+=1
                lines =[]
        
        
        if lines:  # remaining lines
            with open(f'{large_file}_part{part}.txt', 'w') as f:
                f.writelines(lines)


split_large_file('largefile',100)

# %% [markdown]
# ### Assignment 11: Creating a Log File
#
# Write a function that creates a log file named `activity.log` and writes log messages with timestamps.

# %%
import datetime as dt
def log_file(message, filename='log.txt'):
    with open(filename, 'a') as f:
        f.write(f'{dt.datetime.now().isoformat()}: {message}\n')

log_file('Hello World')
